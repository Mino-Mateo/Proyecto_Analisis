# %%
import pymongo
import couchdb

# Conexión a MongoDB
mongo_client = pymongo.MongoClient('mongodb://localhost:27017/')
mongo_db = mongo_client['Nombre de la base de datos']
mongo_collection = mongo_db['Nombre de la colleccion']

# Conexión a CouchDB
#Cambiar credenciales si esq en su caso son otras diferentes
couch = couchdb.Server('http://admin:admin@localhost:5984')  # Modifica el URL y agrega tus credenciales
couch_db_name = 'Nombre de la base de datos en couchdb'

# Verificar si la base de datos existe en CouchDB y crearla si no existe
if couch_db_name not in couch:
    couch.create(couch_db_name)

# Obtener la base de datos en CouchDB
couch_db = couch[couch_db_name]

# Verificar si la base de datos en CouchDB existe y crearla si no existe
if not couch_db.get('_design/' + mongo_collection.name):
    couch_db.save({'_id': '_design/' + mongo_collection.name, 'views': {}})

# Exportar los datos de MongoDB
documents = mongo_collection.find({})

# Transferir los documentos a CouchDB
for document in documents:
    # Eliminar el campo '_id', ya que CouchDB utiliza su propio campo '_id'
    if '_id' in document:
        del document['_id']

    # Agregar el documento a CouchDB
    couch_db.save(document)

mongo_client.close()

# %%
import pymongo
import couchdb

# Conexión a MongoDB
mongo_client = pymongo.MongoClient('mongodb://localhost:27017/')
mongo_db = mongo_client['Eventos_mundiales']
mongo_collection = mongo_db['Eventos_mundiales']

# Conexión a CouchDB
couch = couchdb.Server('http://admin:admin@localhost:5984')  # Modifica el URL y agrega tus credenciales
couch_db_name = 'eventos_mundiales'

# Verificar si la base de datos existe en CouchDB y crearla si no existe
if couch_db_name not in couch:
    couch.create(couch_db_name)

# Obtener la base de datos en CouchDB
couch_db = couch[couch_db_name]

# Verificar si la colección en CouchDB existe y crearla si no existe
if not couch_db.get('_design/' + mongo_collection.name):
    couch_db.save({'_id': '_design/' + mongo_collection.name, 'views': {}})

# Exportar los datos de MongoDB
documents = mongo_collection.find({})

# Transferir los documentos a CouchDB
for document in documents:
    # Eliminar el campo '_id', ya que CouchDB utiliza su propio campo '_id'
    if '_id' in document:
        del document['_id']

    # Agregar el documento a CouchDB
    couch_db.save(document)

mongo_client.close()

# %%
import pymongo
import couchdb

# Conexión a MongoDB
mongo_client = pymongo.MongoClient('mongodb://localhost:27017/')
mongo_db = mongo_client['Conciertos']
mongo_collection = mongo_db['Conciertos']

# Conexión a CouchDB
couch = couchdb.Server('http://admin:admin@localhost:5984')  # Modifica el URL y agrega tus credenciales
couch_db_name = 'concert_2019-2020'

# Verificar si la base de datos existe en CouchDB y crearla si no existe
if couch_db_name not in couch:
    couch.create(couch_db_name)

# Obtener la base de datos en CouchDB
couch_db = couch[couch_db_name]

# Verificar si la colección en CouchDB existe y crearla si no existe
if not couch_db.get('_design/' + mongo_collection.name):
    couch_db.save({'_id': '_design/' + mongo_collection.name, 'views': {}})

# Exportar los datos de MongoDB
documents = mongo_collection.find({})

# Transferir los documentos a CouchDB
for document in documents:
    # Eliminar el campo '_id', ya que CouchDB utiliza su propio campo '_id'
    if '_id' in document:
        del document['_id']

    # Agregar el documento a CouchDB
    couch_db.save(document)

mongo_client.close()

# %%
import pymongo
import couchdb

# Conexión a MongoDB
mongo_client = pymongo.MongoClient('mongodb://localhost:27017/')
mongo_db = mongo_client['Covid-19']
mongo_collection = mongo_db['Covid-19']

# Conexión a CouchDB
couch = couchdb.Server('http://admin:admin@localhost:5984')  # Modifica el URL y agrega tus credenciales
couch_db_name = 'covid-19'

# Verificar si la base de datos existe en CouchDB y crearla si no existe
if couch_db_name not in couch:
    couch.create(couch_db_name)

# Obtener la base de datos en CouchDB
couch_db = couch[couch_db_name]

# Verificar si la colección en CouchDB existe y crearla si no existe
if not couch_db.get('_design/' + mongo_collection.name):
    couch_db.save({'_id': '_design/' + mongo_collection.name, 'views': {}})

# Exportar los datos de MongoDB
documents = mongo_collection.find({})

# Transferir los documentos a CouchDB
for document in documents:
    # Eliminar el campo '_id', ya que CouchDB utiliza su propio campo '_id'
    if '_id' in document:
        del document['_id']

    # Agregar el documento a CouchDB
    couch_db.save(document)

mongo_client.close()

# %%
import pymongo
import couchdb

# Conexión a MongoDB
mongo_client = pymongo.MongoClient('mongodb://localhost:27017/')
mongo_db = mongo_client['Estadisticas_transporte']
mongo_collection = mongo_db['Estadisticas_transporte']

# Conexión a CouchDB
couch = couchdb.Server('http://admin:admin@localhost:5984')  # Modifica el URL y agrega tus credenciales
couch_db_name = 'estadisticas_transporte'

# Verificar si la base de datos existe en CouchDB y crearla si no existe
if couch_db_name not in couch:
    couch.create(couch_db_name)

# Obtener la base de datos en CouchDB
couch_db = couch[couch_db_name]

# Verificar si la colección en CouchDB existe y crearla si no existe
if not couch_db.get('_design/' + mongo_collection.name):
    couch_db.save({'_id': '_design/' + mongo_collection.name, 'views': {}})

# Exportar los datos de MongoDB
documents = mongo_collection.find({})

# Transferir los documentos a CouchDB
for document in documents:
    # Eliminar el campo '_id', ya que CouchDB utiliza su propio campo '_id'
    if '_id' in document:
        del document['_id']

    # Agregar el documento a CouchDB
    couch_db.save(document)

mongo_client.close()

# %%
import pymongo
import couchdb

# Conexión a MongoDB
mongo_client = pymongo.MongoClient('mongodb://localhost:27017/')
mongo_db = mongo_client['Partidos_politicos']
mongo_collection = mongo_db['Partidos_politicos']

# Conexión a CouchDB
couch = couchdb.Server('http://admin:admin@localhost:5984')  # Modifica el URL y agrega tus credenciales
couch_db_name = 'partidos_politicos'

# Verificar si la base de datos existe en CouchDB y crearla si no existe
if couch_db_name not in couch:
    couch.create(couch_db_name)

# Obtener la base de datos en CouchDB
couch_db = couch[couch_db_name]

# Verificar si la colección en CouchDB existe y crearla si no existe
if not couch_db.get('_design/' + mongo_collection.name):
    couch_db.save({'_id': '_design/' + mongo_collection.name, 'views': {}})

# Exportar los datos de MongoDB
documents = mongo_collection.find({})

# Transferir los documentos a CouchDB
for document in documents:
    # Eliminar el campo '_id', ya que CouchDB utiliza su propio campo '_id'
    if '_id' in document:
        del document['_id']

    # Agregar el documento a CouchDB
    couch_db.save(document)

mongo_client.close()

# %%
import pymongo
import couchdb

# Conexión a MongoDB
mongo_client = pymongo.MongoClient('mongodb://localhost:27017/')
mongo_db = mongo_client['Restaurantes']
mongo_collection = mongo_db['Restaurantes']

# Conexión a CouchDB
couch = couchdb.Server('http://admin:admin@localhost:5984')  # Modifica el URL y agrega tus credenciales
couch_db_name = 'restaurantes'

# Verificar si la base de datos existe en CouchDB y crearla si no existe
if couch_db_name not in couch:
    couch.create(couch_db_name)

# Obtener la base de datos en CouchDB
couch_db = couch[couch_db_name]

# Verificar si la colección en CouchDB existe y crearla si no existe
if not couch_db.get('_design/' + mongo_collection.name):
    couch_db.save({'_id': '_design/' + mongo_collection.name, 'views': {}})

# Exportar los datos de MongoDB
documents = mongo_collection.find({})

# Transferir los documentos a CouchDB
for document in documents:
    # Eliminar el campo '_id', ya que CouchDB utiliza su propio campo '_id'
    if '_id' in document:
        del document['_id']

    # Agregar el documento a CouchDB
    couch_db.save(document)

mongo_client.close()

# %%
import pymongo
import couchdb

# Conexión a MongoDB
mongo_client = pymongo.MongoClient('mongodb://localhost:27017/')
mongo_db = mongo_client['hobbylist']
mongo_collection = mongo_db['hobbylist']

# Conexión a CouchDB
couch = couchdb.Server('http://admin:admin@localhost:5984')  # Modifica el URL y agrega tus credenciales
couch_db_name = 'hobbylist'

# Verificar si la base de datos existe en CouchDB y crearla si no existe
if couch_db_name not in couch:
    couch.create(couch_db_name)

# Obtener la base de datos en CouchDB
couch_db = couch[couch_db_name]

# Verificar si la colección en CouchDB existe y crearla si no existe
if not couch_db.get('_design/' + mongo_collection.name):
    couch_db.save({'_id': '_design/' + mongo_collection.name, 'views': {}})

# Exportar los datos de MongoDB
documents = mongo_collection.find({})

# Transferir los documentos a CouchDB
for document in documents:
    # Eliminar el campo '_id', ya que CouchDB utiliza su propio campo '_id'
    if '_id' in document:
        del document['_id']

    # Agregar el documento a CouchDB
    couch_db.save(document)

mongo_client.close()

# %%
import pymongo
import couchdb

# Conexión a MongoDB
mongo_client = pymongo.MongoClient('mongodb://localhost:27017/')
mongo_db = mongo_client['pokemon']
mongo_collection = mongo_db['pokemon']

# Conexión a CouchDB
couch = couchdb.Server('http://admin:admin@localhost:5984')  # Modifica el URL y agrega tus credenciales
couch_db_name = 'pokemon'

# Verificar si la base de datos existe en CouchDB y crearla si no existe
if couch_db_name not in couch:
    couch.create(couch_db_name)

# Obtener la base de datos en CouchDB
couch_db = couch[couch_db_name]

# Verificar si la colección en CouchDB existe y crearla si no existe
if not couch_db.get('_design/' + mongo_collection.name):
    couch_db.save({'_id': '_design/' + mongo_collection.name, 'views': {}})

# Exportar los datos de MongoDB
documents = mongo_collection.find({})

# Transferir los documentos a CouchDB
for document in documents:
    # Eliminar el campo '_id', ya que CouchDB utiliza su propio campo '_id'
    if '_id' in document:
        del document['_id']

    # Agregar el documento a CouchDB
    couch_db.save(document)

mongo_client.close()

# %%
import pymongo
import couchdb

# Conexión a MongoDB
mongo_client = pymongo.MongoClient('mongodb://localhost:27017/')
mongo_db = mongo_client['trasporte_ecuador_2015']
mongo_collection = mongo_db['trasporte_ecuador_2015']

# Conexión a CouchDB
couch = couchdb.Server('http://admin:admin@localhost:5984')  # Modifica el URL y agrega tus credenciales
couch_db_name = 'trasporte_ecuador_2015'

# Verificar si la base de datos existe en CouchDB y crearla si no existe
if couch_db_name not in couch:
    couch.create(couch_db_name)

# Obtener la base de datos en CouchDB
couch_db = couch[couch_db_name]

# Verificar si la colección en CouchDB existe y crearla si no existe
if not couch_db.get('_design/' + mongo_collection.name):
    couch_db.save({'_id': '_design/' + mongo_collection.name, 'views': {}})

# Exportar los datos de MongoDB
documents = mongo_collection.find({})

# Transferir los documentos a CouchDB
for document in documents:
    # Eliminar el campo '_id', ya que CouchDB utiliza su propio campo '_id'
    if '_id' in document:
        del document['_id']

    # Agregar el documento a CouchDB
    couch_db.save(document)

mongo_client.close()
