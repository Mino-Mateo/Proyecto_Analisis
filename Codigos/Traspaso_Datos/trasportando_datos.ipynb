# %%
import pymongo
import couchdb

# %%
# Estableciendo conexion con Mongodb
mongo_client = pymongo.MongoClient('mongodb://localhost:27017/')
mongo_db = mongo_client['nombre de la base de datos']  
mongo_collection = mongo_db['nombre de la colleccion']  

# Estableciendo conexion con Couchdb 
#Modificar credenciales si esq en su caso sean otras diferentes
couch = couchdb.Server('http://admin:admin@localhost:5984')  # Modificando el url y agregando nuestras credenciales
couch_db = couch['nombre de la base de datos']

# Exportando los datos de Mongodb
documents = mongo_collection.find({})  

# Tranfireindo los documentos a CouchDB
for document in documents:
    # Ya que en Mongodb nos crea un id, este debemos borrarla para que no nos cree ningun problema en Couchdb
    if '_id' in document:
        del document['_id']

    # Agregar el documento a CouchDB
    couch_db.save(document)


mongo_client.close()

# %%
mongo_client = pymongo.MongoClient('mongodb://localhost:27017/')
mongo_db = mongo_client['Proyecto_analisis']  
mongo_collection = mongo_db['Eventos o noticias mundiales']  

# Estableciendo conexion con Couchdb 
couch = couchdb.Server('http://admin:admin@localhost:5984')  # Modificando el url y agregando nuestras credenciales
couch_db = couch['eventos_noticas_mundiales']

# Exportando los datos de Mongodb
documents = mongo_collection.find({})  

# Tranfireindo los documentos a CouchDB
for document in documents:
    # Ya que en Mongodb nos crea un id, este debemos borrarla para que no nos cree ningun problema en Couchdb
    if '_id' in document:
        del document['_id']

    # Agregar el documento a CouchDB
    couch_db.save(document)


mongo_client.close()

# %%
mongo_client = pymongo.MongoClient('mongodb://localhost:27017/')
mongo_db = mongo_client['Proyecto_analisis']  
mongo_collection = mongo_db['Restaurantes']  

# Estableciendo conexion con Couchdb 
couch = couchdb.Server('http://admin:admin@localhost:5984')  # Modificando el url y agregando nuestras credenciales
couch_db = couch['restaurantes']

# Exportando los datos de Mongodb
documents = mongo_collection.find({})  

# Tranfireindo los documentos a CouchDB
for document in documents:
    # Ya que en Mongodb nos crea un id, este debemos borrarla para que no nos cree ningun problema en Couchdb
    if '_id' in document:
        del document['_id']

    # Agregar el documento a CouchDB
    couch_db.save(document)


mongo_client.close()
# Out:
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
mongo_client = pymongo.MongoClient('mongodb://localhost:27017/')
mongo_db = mongo_client['Proyecto_analisis']  
mongo_collection = mongo_db['concert_2019_2020']  

# Estableciendo conexion con Couchdb 
couch = couchdb.Server('http://admin:admin@localhost:5984')  # Modificando el url y agregando nuestras credenciales
couch_db = couch['concert_2019_2020']

# Exportando los datos de Mongodb
documents = mongo_collection.find({})  

# Tranfireindo los documentos a CouchDB
for document in documents:
    # Ya que en Mongodb nos crea un id, este debemos borrarla para que no nos cree ningun problema en Couchdb
    if '_id' in document:
        del document['_id']

    # Agregar el documento a CouchDB
    couch_db.save(document)


mongo_client.close()

# %%
mongo_client = pymongo.MongoClient('mongodb://localhost:27017/')
mongo_db = mongo_client['Proyecto_analisis']  
mongo_collection = mongo_db['covid-19']  

# Estableciendo conexion con Couchdb 
couch = couchdb.Server('http://admin:admin@localhost:5984')  # Modificando el url y agregando nuestras credenciales
couch_db = couch['covid-19']

# Exportando los datos de Mongodb
documents = mongo_collection.find({})  

# Tranfireindo los documentos a CouchDB
for document in documents:
    # Ya que en Mongodb nos crea un id, este debemos borrarla para que no nos cree ningun problema en Couchdb
    if '_id' in document:
        del document['_id']

    # Agregar el documento a CouchDB
    couch_db.save(document)


mongo_client.close()

# %%
mongo_client = pymongo.MongoClient('mongodb://localhost:27017/')
mongo_db = mongo_client['Proyecto_analisis']  
mongo_collection = mongo_db['hobbylist']  

# Estableciendo conexion con Couchdb 
couch = couchdb.Server('http://admin:admin@localhost:5984')  # Modificando el url y agregando nuestras credenciales
couch_db = couch['hobbylist']

# Exportando los datos de Mongodb
documents = mongo_collection.find({})  

# Tranfireindo los documentos a CouchDB
for document in documents:
    # Ya que en Mongodb nos crea un id, este debemos borrarla para que no nos cree ningun problema en Couchdb
    if '_id' in document:
        del document['_id']

    # Agregar el documento a CouchDB
    couch_db.save(document)


mongo_client.close()

# %%
mongo_client = pymongo.MongoClient('mongodb://localhost:27017/')
mongo_db = mongo_client['Proyecto_analisis']  
mongo_collection = mongo_db['partidospoliticos']  

# Estableciendo conexion con Couchdb 
couch = couchdb.Server('http://admin:admin@localhost:5984')  # Modificando el url y agregando nuestras credenciales
couch_db = couch['partidos_politicos']

# Exportando los datos de Mongodb
documents = mongo_collection.find({})  

# Tranfireindo los documentos a CouchDB
for document in documents:
    # Ya que en Mongodb nos crea un id, este debemos borrarla para que no nos cree ningun problema en Couchdb
    if '_id' in document:
        del document['_id']

    # Agregar el documento a CouchDB
    couch_db.save(document)


mongo_client.close()

# %%
mongo_client = pymongo.MongoClient('mongodb://localhost:27017/')
mongo_db = mongo_client['Proyecto_analisis']  
mongo_collection = mongo_db['pokemon']  

# Estableciendo conexion con Couchdb 
couch = couchdb.Server('http://admin:admin@localhost:5984')  # Modificando el url y agregando nuestras credenciales
couch_db = couch['pokemon']

# Exportando los datos de Mongodb
documents = mongo_collection.find({})  

# Tranfireindo los documentos a CouchDB
for document in documents:
    # Ya que en Mongodb nos crea un id, este debemos borrarla para que no nos cree ningun problema en Couchdb
    if '_id' in document:
        del document['_id']

    # Agregar el documento a CouchDB
    couch_db.save(document)


mongo_client.close()

# %%
mongo_client = pymongo.MongoClient('mongodb://localhost:27017/')
mongo_db = mongo_client['Proyecto_analisis']  
mongo_collection = mongo_db['transporte_ecuador_2015']  

# Estableciendo conexion con Couchdb 
couch = couchdb.Server('http://admin:admin@localhost:5984')  # Modificando el url y agregando nuestras credenciales
couch_db = couch['transporte_ecuador_2015']

# Exportando los datos de Mongodb
documents = mongo_collection.find({})  

# Tranfireindo los documentos a CouchDB
for document in documents:
    # Ya que en Mongodb nos crea un id, este debemos borrarla para que no nos cree ningun problema en Couchdb
    if '_id' in document:
        del document['_id']

    # Agregar el documento a CouchDB
    couch_db.save(document)


mongo_client.close()
