# %%
# Importar SQLite
#import sqlite3

# Conectarse a SQLite
#con = sqlite3.connect("database.db")

# %%
# Importar librerias
import csv
import couchdb as db

# Creacion y Conexion CouchDB Partidos Politicos
couch = db.Server('http://admin:admin@localhost:5984')
db = couch.create('partidos_politicos')
db = couch['partidos_politicos']

# Función para convertir CSV a JSON
def csv_to_json(csv_file_path):
    data = []
    with open(csv_file_path, "r", encoding="utf-8") as csv_archivo:
        csv_reader = csv.DictReader(csv_archivo)
        for row in csv_reader:
            data.append(row)
    return data

# Ruta de acceso del archivo CSV
archivo_csv = "../Bases_Datos/CSV/partidospoliticos.csv"

# Convertir CSV a JSON
documentos_json = csv_to_json(archivo_csv)

# Guardado de archivos
for documento in documentos_json:
    db.save(documento)

# %%
# Importar librerias
import csv
import couchdb as db

# Creacion y Conexion CouchDB Eventos/Noticias Mundiales
couch = db.Server('http://admin:admin@localhost:5984')
db = couch.create('eventos_noticias_mundiales')
db = couch['eventos_noticias_mundiales']

# Función para convertir CSV a JSON
def csv_to_json(csv_file_path):
    data = []
    with open(csv_file_path, "r", encoding="utf-8") as csv_archivo:
        csv_reader = csv.DictReader(csv_archivo)
        for row in csv_reader:
            data.append(row)
    return data

# Ruta de acceso del archivo CSV
archivo_csv = "../Bases_Datos/CSV/Eventos o noticias mundiales.csv"

# Convertir CSV a JSON
documentos_json = csv_to_json(archivo_csv)

# Guardado de archivos
for documento in documentos_json:
    db.save(documento)

# %%
# Importar librerias
import csv
import couchdb as db

# Creacion y Conexion CouchDB Restaurantes y Esparcimiento
couch = db.Server('http://admin:admin@localhost:5984')
db = couch.create('restaurantes_sitios')
db = couch['restaurantes_sitios']

# Función para convertir CSV a JSON
def csv_to_json(csv_file_path):
    data = []
    with open(csv_file_path, "r", encoding="utf-8") as csv_archivo:
        csv_reader = csv.DictReader(csv_archivo)
        for row in csv_reader:
            data.append(row)
    return data

# Ruta de acceso del archivo CSV
archivo_csv = "../Bases_Datos/CSV/Restaurantes y sitios de esparcimiento.csv"

# Convertir CSV a JSON
documentos_json = csv_to_json(archivo_csv)

# Guardado de archivos
for documento in documentos_json:
    db.save(documento)

# %%
# Importar librerias
import csv
import couchdb as db

# Creacion y Conexion CouchDB Conciertos
couch = db.Server('http://admin:admin@localhost:5984')
db = couch.create('conciertos')
db = couch['conciertos']

# Función para convertir CSV a JSON
def csv_to_json(csv_file_path):
    data = []
    with open(csv_file_path, "r", encoding="utf-8") as csv_archivo:
        csv_reader = csv.DictReader(csv_archivo)
        for row in csv_reader:
            data.append(row)
    return data

# Ruta de acceso del archivo CSV
archivo_csv = "../Bases_Datos/CSV/BF_Concert_2019-2020.csv"

# Convertir CSV a JSON
documentos_json = csv_to_json(archivo_csv)

# Guardado de archivos
for documento in documentos_json:
    db.save(documento)

# %%
# Importar librerias
import csv
import couchdb as db

# Creacion y Conexion CouchDB Hobbies
couch = db.Server('http://admin:admin@localhost:5984')
db = couch.create('hobbies')
db = couch['hobbies']

# Función para convertir CSV a JSON
def csv_to_json(csv_file_path):
    data = []
    with open(csv_file_path, "r", encoding="utf-8") as csv_archivo:
        csv_reader = csv.DictReader(csv_archivo)
        for row in csv_reader:
            data.append(row)
    return data

# Ruta de acceso del archivo CSV
archivo_csv = "../Bases_Datos/CSV/hobbylist.csv"

# Convertir CSV a JSON
documentos_json = csv_to_json(archivo_csv)

# Guardado de archivos
for documento in documentos_json:
    db.save(documento)
