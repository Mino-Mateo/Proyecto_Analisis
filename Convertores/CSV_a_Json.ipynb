# %%
# Importar SQLite
#import sqlite3

# Conectarse a SQLite
#con = sqlite3.connect("database.db")

# %%
# Librerias
import csv
import couchdb as db
from pymongo import MongoClient
import redis
import json


# Conexion CouchDB 
couch = db.Server('http://admin:admin@localhost:5984')
db_name_couch = 'conciertos'

# Conexion MongoDB
mongo_client = MongoClient('localhost', 27017)
db_mongo = mongo_client['conciertos']

# Conexion Redis
redis_client = redis.StrictRedis(host='localhost', port=6379, db=0)


# Verificar si existe la base de datos
if db_name_couch in couch:
    db_couch = couch[db_name_couch]
else:
    db_couch = couch.create(db_name_couch)


# Función para convertir CSV a JSON
def csv_to_json(csv_file_path):
    data = []
    with open(csv_file_path, "r", encoding="utf-8") as csv_archivo:
        csv_reader = csv.DictReader(csv_archivo)
        for row in csv_reader:
            data.append(row)
    return data

# Ruta de acceso del archivo CSV
archivo_csv = "../Bases_Datos/CSV/BF_Concert_2019-2020.csv"

# Convertir CSV a JSON
documentos_json = csv_to_json(archivo_csv)


# Guardado de archivos
for documento in documentos_json:

    # Guardar en CouchDB
    try:
        db_couch.save(documento)
    except Exception as e:
        print(f"Error al guardar en CouchDB")

    # Guardar en MongoDB
    try:
        db_mongo['conciertos'].insert_one(documento)
    except Exception as e:
        print(f"Error al guardar en MongoDB")

    # Guardar en Redis
    try:
        redis_client.set(documento['_id'], json.dumps(documento))
    except Exception as e:
        print(f"Error al guardar en Redis")

# %%
# Librerias
import csv
import couchdb as db
from pymongo import MongoClient
import redis
import json


# Conexion CouchDB 
couch = db.Server('http://admin:admin@localhost:5984')
db_name_couch = 'eventos_mundiales'

# Conexion MongoDB
mongo_client = MongoClient('localhost', 27017)
db_mongo = mongo_client['eventos_mundiales']

# Conexion Redis
redis_client = redis.StrictRedis(host='localhost', port=6379, db=0)


# Verificar si existe la base de datos
if db_name_couch in couch:
    db_couch = couch[db_name_couch]
else:
    db_couch = couch.create(db_name_couch)


# Función para convertir CSV a JSON
def csv_to_json(csv_file_path):
    data = []
    with open(csv_file_path, "r", encoding="utf-8") as csv_archivo:
        csv_reader = csv.DictReader(csv_archivo)
        for row in csv_reader:
            data.append(row)
    return data

# Ruta de acceso del archivo CSV
archivo_csv = "../Bases_Datos/CSV/Eventos o noticias mundiales.csv"

# Convertir CSV a JSON
documentos_json = csv_to_json(archivo_csv)


# Guardado de archivos
for documento in documentos_json:

    # Guardar en CouchDB
    try:
        db_couch.save(documento)
    except Exception as e:
        print(f"Error al guardar en CouchDB")

    # Guardar en MongoDB
    try:
        db_mongo['eventos_mundiales'].insert_one(documento)
    except Exception as e:
        print(f"Error al guardar en MongoDB")

    # Guardar en Redis
    try:
        redis_client.set(documento['_id'], json.dumps(documento))
    except Exception as e:
        print(f"Error al guardar en Redis")

# %%
# Librerias
import csv
import couchdb as db
from pymongo import MongoClient
import redis
import json


# Conexion CouchDB 
couch = db.Server('http://admin:admin@localhost:5984')
db_name_couch = 'hobbies'

# Conexion MongoDB
mongo_client = MongoClient('localhost', 27017)
db_mongo = mongo_client['hobbies']

# Conexion Redis
redis_client = redis.StrictRedis(host='localhost', port=6379, db=0)


# Verificar si existe la base de datos
if db_name_couch in couch:
    db_couch = couch[db_name_couch]
else:
    db_couch = couch.create(db_name_couch)


# Función para convertir CSV a JSON
def csv_to_json(csv_file_path):
    data = []
    with open(csv_file_path, "r", encoding="utf-8") as csv_archivo:
        csv_reader = csv.DictReader(csv_archivo)
        for row in csv_reader:
            data.append(row)
    return data

# Ruta de acceso del archivo CSV
archivo_csv = "../Bases_Datos/CSV/hobbylist.csv"

# Convertir CSV a JSON
documentos_json = csv_to_json(archivo_csv)


# Guardado de archivos
for documento in documentos_json:

    # Guardar en CouchDB
    try:
        db_couch.save(documento)
    except Exception as e:
        print(f"Error al guardar en CouchDB")

    # Guardar en MongoDB
    try:
        db_mongo['hobbies'].insert_one(documento)
    except Exception as e:
        print(f"Error al guardar en MongoDB")

    # Guardar en Redis
    try:
        redis_client.set(documento['_id'], json.dumps(documento))
    except Exception as e:
        print(f"Error al guardar en Redis")

# %%
# Librerias
import csv
import couchdb as db
from pymongo import MongoClient
import redis
import json


# Conexion CouchDB 
couch = db.Server('http://admin:admin@localhost:5984')
db_name_couch = 'inec'

# Conexion MongoDB
mongo_client = MongoClient('localhost', 27017)
db_mongo = mongo_client['inec']

# Conexion Redis
redis_client = redis.StrictRedis(host='localhost', port=6379, db=0)


# Verificar si existe la base de datos
if db_name_couch in couch:
    db_couch = couch[db_name_couch]
else:
    db_couch = couch.create(db_name_couch)


# Función para convertir CSV a JSON
def csv_to_json(csv_file_path):
    data = []
    with open(csv_file_path, "r", encoding="utf-8") as csv_archivo:
        csv_reader = csv.DictReader(csv_archivo)
        for row in csv_reader:
            data.append(row)
    return data

# Ruta de acceso del archivo CSV
archivo_csv = "../Bases_Datos/CSV/INEC_Estadísticas de Transporte_BDD_2014_2020.csv"

# Convertir CSV a JSON
documentos_json = csv_to_json(archivo_csv)


# Guardado de archivos
for documento in documentos_json:

    # Guardar en CouchDB
    try:
        db_couch.save(documento)
    except Exception as e:
        print(f"Error al guardar en CouchDB")

    # Guardar en MongoDB
    try:
        db_mongo['inec'].insert_one(documento)
    except Exception as e:
        print(f"Error al guardar en MongoDB")

    # Guardar en Redis
    try:
        redis_client.set(documento['_id'], json.dumps(documento))
    except Exception as e:
        print(f"Error al guardar en Redis")
# Out:
# [1,31m---------------------------------------------------------------------------
# [1,31mKeyboardInterrupt                         Traceback (most recent call last)
# Cell [1,32mIn[27], line 49
# [0,32m     45 for[39,00m documento in[39,00m documentos_json:
# [0,32m     46
# [0,32m     47     # Guardar en CouchDB[39,00m
# [0,32m     48     try[39,00m:
# [1,32m---> 49         db_couch.[39,49msave(documento)
# [0,32m     50     except[39,00m Exception[39,00m as[39,00m e:
# [0,32m     51         print(f"Error al guardar en CouchDB")
#
# File [1,32mc:\Users\ESTUDIOS-EPN\AppData\Local\Programs\Python\Python311\Lib\site-packages\couchdb\client.py:529, in [0,36mDatabase.save[1,34m(self, doc, **options)
# [0,32m    527 else[39,00m:
# [0,32m    528     func = self.resource.post_json
# [1,32m--> 529 _, _, data = func(body=[39,49mdoc, *[39,49m*[39,49moptions)
# [0,32m    530 id, rev = data['id'], data.get('rev')
# [0,32m    531 doc['_id'] = id
#
# File [1,32mc:\Users\ESTUDIOS-EPN\AppData\Local\Programs\Python\Python311\Lib\site-packages\couchdb\http.py:573, in [0,36mResource.post_json[1,34m(self, path, body, headers, **params)
# [0,32m    572 def[39,00m post_json(self, path=None[39,00m, body=None[39,00m, headers=None[39,00m, **params):
# [1,32m--> 573     return[39,00m self[39,49m.[39,49m_request_json('[39,49mPOST[39,49m'[39,49m, path, body=[39,49mbody, headers=[39,49mheaders,
# [0,32m    574                               *[39,49m*[39,49mparams)
#
# File [1,32mc:\Users\ESTUDIOS-EPN\AppData\Local\Programs\Python\Python311\Lib\site-packages\couchdb\http.py:595, in [0,36mResource._request_json[1,34m(self, method, path, body, headers, **params)
# [0,32m    594 def[39,00m _request_json(self, method, path=None[39,00m, body=None[39,00m, headers=None[39,00m, **params):
# [1,32m--> 595     status, headers, data = self[39,49m.[39,49m_request(method, path, body=[39,49mbody,
# [0,32m    596                                           headers=[39,49mheaders, *[39,49m*[39,49mparams)
# [0,32m    597     if[39,00m 'application/json' in[39,00m headers.get('content-type', ''):
# [0,32m    598         data = json.decode(data.read().decode('utf-8'))
#
# File [1,32mc:\Users\ESTUDIOS-EPN\AppData\Local\Programs\Python\Python311\Lib\site-packages\couchdb\http.py:590, in [0,36mResource._request[1,34m(self, method, path, body, headers, **params)
# [0,32m    588 else[39,00m:
# [0,32m    589     url = urljoin(self.url, **params)
# [1,32m--> 590 return[39,00m self[39,49m.[39,49msession.[39,49mrequest(method, url, body=[39,49mbody,
# [0,32m    591                             headers=[39,49mall_headers,
# [0,32m    592                             credentials=[39,49mself[39,49m.[39,49mcredentials)
#
# File [1,32mc:\Users\ESTUDIOS-EPN\AppData\Local\Programs\Python\Python311\Lib\site-packages\couchdb\http.py:349, in [0,36mSession.request[1,34m(self, method, url, body, headers, credentials, num_redirects)
# [0,32m    346         else[39,00m:
# [0,32m    347             raise[39,00m
# [1,32m--> 349 resp = _try_request_with_retries(iter[39,49m(self[39,49m.[39,49mretry_delays))
# [0,32m    350 status = resp.status
# [0,32m    352 # Handle conditional response[39,00m
#
# File [1,32mc:\Users\ESTUDIOS-EPN\AppData\Local\Programs\Python\Python311\Lib\site-packages\couchdb\http.py:300, in [0,36mSession.request.<locals>._try_request_with_retries[1,34m(retries)
# [0,32m    298 while[39,00m True[39,00m:
# [0,32m    299     try[39,00m:
# [1,32m--> 300         return[39,00m _try_request()
# [0,32m    301     except[39,00m socket.error as[39,00m e:
# [0,32m    302         ecode = e.args[0]
#
# File [1,32mc:\Users\ESTUDIOS-EPN\AppData\Local\Programs\Python\Python311\Lib\site-packages\couchdb\http.py:338, in [0,36mSession.request.<locals>._try_request[1,34m()
# [0,32m    336                 conn.send(status + chunk + b'\r[39,00m\n[39,00m')
# [0,32m    337             conn.send(b'0\r[39,00m\n[39,00m\r[39,00m\n[39,00m')
# [1,32m--> 338     return[39,00m conn.[39,49mgetresponse()
# [0,32m    339 except[39,00m BadStatusLine as[39,00m e:
# [0,32m    340     # httplib raises a BadStatusLine when it cannot read the status[39,00m
# [0,32m    341     # line saying, "Presumably, the server closed the connection[39,00m
# [0,32m    342     # before sending a valid response."[39,00m
# [0,32m    343     # Raise as ECONNRESET to simplify retry logic.[39,00m
# [0,32m    344     if[39,00m e.line == '' or[39,00m e.line == "''":
#
# File [1,32mc:\Users\ESTUDIOS-EPN\AppData\Local\Programs\Python\Python311\Lib\http\client.py:1378, in [0,36mHTTPConnection.getresponse[1,34m(self)
# [0,32m   1376 try[39,00m:
# [0,32m   1377     try[39,00m:
# [1,32m-> 1378         response.[39,49mbegin()
# [0,32m   1379     except[39,00m ConnectionError[39,00m:
# [0,32m   1380         self.close()
#
# File [1,32mc:\Users\ESTUDIOS-EPN\AppData\Local\Programs\Python\Python311\Lib\http\client.py:318, in [0,36mHTTPResponse.begin[1,34m(self)
# [0,32m    316 # read until we get a non-100 response[39,00m
# [0,32m    317 while[39,00m True[39,00m:
# [1,32m--> 318     version, status, reason = self[39,49m.[39,49m_read_status()
# [0,32m    319     if[39,00m status != CONTINUE:
# [0,32m    320         break[39,00m
#
# File [1,32mc:\Users\ESTUDIOS-EPN\AppData\Local\Programs\Python\Python311\Lib\http\client.py:279, in [0,36mHTTPResponse._read_status[1,34m(self)
# [0,32m    278 def[39,00m _read_status(self):
# [1,32m--> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
# [0,32m    280     if[39,00m len(line) > _MAXLINE:
# [0,32m    281         raise[39,00m LineTooLong("status line")
#
# File [1,32mc:\Users\ESTUDIOS-EPN\AppData\Local\Programs\Python\Python311\Lib\socket.py:706, in [0,36mSocketIO.readinto[1,34m(self, b)
# [0,32m    704 while[39,00m True[39,00m:
# [0,32m    705     try[39,00m:
# [1,32m--> 706         return[39,00m self[39,49m.[39,49m_sock.[39,49mrecv_into(b)
# [0,32m    707     except[39,00m timeout:
# [0,32m    708         self._timeout_occurred = True[39,00m
#
# [1,31mKeyboardInterrupt:

# %%
# Librerias
import csv
import couchdb as db
from pymongo import MongoClient
import redis
import json


# Conexion CouchDB 
couch = db.Server('http://admin:admin@localhost:5984')
db_name_couch = 'partidos_politicos'

# Conexion MongoDB
mongo_client = MongoClient('localhost', 27017)
db_mongo = mongo_client['partidos_politicos']

# Conexion Redis
redis_client = redis.StrictRedis(host='localhost', port=6379, db=0)


# Verificar si existe la base de datos
if db_name_couch in couch:
    db_couch = couch[db_name_couch]
else:
    db_couch = couch.create(db_name_couch)


# Función para convertir CSV a JSON
def csv_to_json(csv_file_path):
    data = []
    with open(csv_file_path, "r", encoding="utf-8") as csv_archivo:
        csv_reader = csv.DictReader(csv_archivo)
        for row in csv_reader:
            data.append(row)
    return data

# Ruta de acceso del archivo CSV
archivo_csv = "../Bases_Datos/CSV/partidospoliticos.csv"

# Convertir CSV a JSON
documentos_json = csv_to_json(archivo_csv)


# Guardado de archivos
for documento in documentos_json:

    # Guardar en CouchDB
    try:
        db_couch.save(documento)
    except Exception as e:
        print(f"Error al guardar en CouchDB")

    # Guardar en MongoDB
    try:
        db_mongo['partidos_politicos'].insert_one(documento)
    except Exception as e:
        print(f"Error al guardar en MongoDB")

    # Guardar en Redis
    try:
        redis_client.set(documento['_id'], json.dumps(documento))
    except Exception as e:
        print(f"Error al guardar en Redis")

# %%
# Librerias
import csv
import couchdb as db
from pymongo import MongoClient
import redis
import json


# Conexion CouchDB 
couch = db.Server('http://admin:admin@localhost:5984')
db_name_couch = 'restaurantes_sitios'

# Conexion MongoDB
mongo_client = MongoClient('localhost', 27017)
db_mongo = mongo_client['restaurantes_sitios']

# Conexion Redis
redis_client = redis.StrictRedis(host='localhost', port=6379, db=0)


# Verificar si existe la base de datos
if db_name_couch in couch:
    db_couch = couch[db_name_couch]
else:
    db_couch = couch.create(db_name_couch)


# Función para convertir CSV a JSON
def csv_to_json(csv_file_path):
    data = []
    with open(csv_file_path, "r", encoding="utf-8") as csv_archivo:
        csv_reader = csv.DictReader(csv_archivo)
        for row in csv_reader:
            data.append(row)
    return data

# Ruta de acceso del archivo CSV
archivo_csv = "../Bases_Datos/CSV/Restaurantes y sitios de esparcimiento.csv"

# Convertir CSV a JSON
documentos_json = csv_to_json(archivo_csv)


# Guardado de archivos
for documento in documentos_json:

    # Guardar en CouchDB
    try:
        db_couch.save(documento)
    except Exception as e:
        print(f"Error al guardar en CouchDB")

    # Guardar en MongoDB
    try:
        db_mongo['restaurantes_sitios'].insert_one(documento)
    except Exception as e:
        print(f"Error al guardar en MongoDB")

    # Guardar en Redis
    try:
        redis_client.set(documento['_id'], json.dumps(documento))
    except Exception as e:
        print(f"Error al guardar en Redis")

# %%
# Librerias
import csv
import couchdb as db
from pymongo import MongoClient
import redis
import json


# Conexion CouchDB 
couch = db.Server('http://admin:admin@localhost:5984')
db_name_couch = 'eventos_deportes'

# Conexion MongoDB
mongo_client = MongoClient('localhost', 27017)
db_mongo = mongo_client['eventos_deportes']

# Conexion Redis
redis_client = redis.StrictRedis(host='localhost', port=6379, db=0)


# Verificar si existe la base de datos
if db_name_couch in couch:
    db_couch = couch[db_name_couch]
else:
    db_couch = couch.create(db_name_couch)


# Función para convertir CSV a JSON
def csv_to_json(csv_file_path):
    data = []
    with open(csv_file_path, "r", encoding="utf-8") as csv_archivo:
        csv_reader = csv.DictReader(csv_archivo)
        for row in csv_reader:
            data.append(row)
    return data

# Ruta de acceso del archivo CSV
archivo_csv = "../Bases_Datos/CSV/Sport_Events.csv"

# Convertir CSV a JSON
documentos_json = csv_to_json(archivo_csv)


# Guardado de archivos
for documento in documentos_json:

    # Guardar en CouchDB
    try:
        db_couch.save(documento)
    except Exception as e:
        print(f"Error al guardar en CouchDB")

    # Guardar en MongoDB
    try:
        db_mongo['eventos_deportes'].insert_one(documento)
    except Exception as e:
        print(f"Error al guardar en MongoDB")

    # Guardar en Redis
    try:
        redis_client.set(documento['_id'], json.dumps(documento))
    except Exception as e:
        print(f"Error al guardar en Redis")

# %%
# Librerias
import csv
import couchdb as db
from pymongo import MongoClient
import redis
import json


# Conexion CouchDB 
couch = db.Server('http://admin:admin@localhost:5984')
db_name_couch = 'transporte_2015'

# Conexion MongoDB
mongo_client = MongoClient('localhost', 27017)
db_mongo = mongo_client['transporte_2015']

# Conexion Redis
redis_client = redis.StrictRedis(host='localhost', port=6379, db=0)


# Verificar si existe la base de datos
if db_name_couch in couch:
    db_couch = couch[db_name_couch]
else:
    db_couch = couch.create(db_name_couch)


# Función para convertir CSV a JSON
def csv_to_json(csv_file_path):
    data = []
    with open(csv_file_path, "r", encoding="utf-8") as csv_archivo:
        csv_reader = csv.DictReader(csv_archivo)
        for row in csv_reader:
            data.append(row)
    return data

# Ruta de acceso del archivo CSV
archivo_csv = "../Bases_Datos/CSV/trasporte_ecuador_2015.csv"

# Convertir CSV a JSON
documentos_json = csv_to_json(archivo_csv)


# Guardado de archivos
for documento in documentos_json:

    # Guardar en CouchDB
    try:
        db_couch.save(documento)
    except Exception as e:
        print(f"Error al guardar en CouchDB")

    # Guardar en MongoDB
    try:
        db_mongo['transporte_2015'].insert_one(documento)
    except Exception as e:
        print(f"Error al guardar en MongoDB")

    # Guardar en Redis
    try:
        redis_client.set(documento['_id'], json.dumps(documento))
    except Exception as e:
        print(f"Error al guardar en Redis")
